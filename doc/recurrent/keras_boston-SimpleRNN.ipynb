# %%
import os, numpy as np
import pandas as pd

os.environ["KERAS_BACKEND"] = "tensorflow"

import keras 
from sklearn import datasets

from sklearn.model_selection import train_test_split

from keras.utils import np_utils


def set_reproducible():
    import tensorflow as tf
    import random as rn
    import os
    os.environ['PYTHONHASHSEED'] = '1960'
    rn.seed(1960)
    np.random.seed(1960)
    session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

    from keras import backend as K
    tf.set_random_seed(1960)

    sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
    K.set_session(sess)

set_reproducible()
# Out:
# Using TensorFlow backend.
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# # Build a Keras Model

# %%
NC = 13

def create_model():
    from keras.models import Sequential
    from keras.layers import Dense, Activation, SimpleRNN

    model = Sequential()
    model.add(SimpleRNN(3, input_shape=(1, NC), batch_size=1 , stateful=True))
    model.add(Dense(1))
    model.compile(optimizer='rmsprop', loss='mse')
    return model

# %%
boston  = datasets.load_boston()
train_X, test_X, train_y, test_y = train_test_split(boston.data, boston.target, train_size=0.6, test_size=0.4, random_state=1960)
train_X = train_X.reshape(train_X.shape[0] , 1, train_X.shape[1])
test_X = test_X.reshape(test_X.shape[0] , 1, test_X.shape[1])

# %%
#boston.data

# %%
#boston.target

# %%
from keras.wrappers.scikit_learn import KerasRegressor

clf = KerasRegressor(build_fn=create_model, batch_size=1, epochs=12, verbose=2)

print(train_X.shape , train_y.shape)
clf.fit(train_X, train_y)
# Out:
# (303, 1, 13) (303,)
# SIMPLERNNCELL_CALL_IN Tensor("simple_rnn_1/strided_slice_1:0", shape=(1, 13), dtype=float32) [<tf.Variable 'simple_rnn_1/Variable:0' shape=(1, 3) dtype=float32_ref>]
# SIMPLERNNCELL_CALL_OUT Tensor("simple_rnn_1/Tanh:0", shape=(1, 3), dtype=float32) [<tf.Tensor 'simple_rnn_1/Tanh:0' shape=(1, 3) dtype=float32>]
# SIMPLERNNCELL_CALL_IN Tensor("simple_rnn_1/while/TensorArrayReadV3:0", shape=(1, 13), dtype=float32) (<tf.Tensor 'simple_rnn_1/while/Identity_2:0' shape=(1, 3) dtype=float32>,)
# SIMPLERNNCELL_CALL_OUT Tensor("simple_rnn_1/while/Tanh:0", shape=(1, 3), dtype=float32) [<tf.Tensor 'simple_rnn_1/while/Tanh:0' shape=(1, 3) dtype=float32>]
# RNN_LAYER_CALL_IN Tensor("simple_rnn_1_input:0", shape=(1, 1, 13), dtype=float32) [<tf.Variable 'simple_rnn_1/Variable:0' shape=(1, 3) dtype=float32_ref>]
# RNN_LAYER_CALL_OUT Tensor("simple_rnn_1/TensorArrayReadV3:0", shape=(1, 3), dtype=float32) (<tf.Tensor 'simple_rnn_1/while/Exit_2:0' shape=(1, 3) dtype=float32>,)
# Epoch 1/12
#  - 1s - loss: 613.3924
# Epoch 2/12
#  - 0s - loss: 571.3568
# Epoch 3/12
#  - 0s - loss: 530.5643
# Epoch 4/12
#  - 0s - loss: 492.1889
# Epoch 5/12
#  - 0s - loss: 451.7092
# Epoch 6/12
#  - 0s - loss: 408.7775
# Epoch 7/12
#  - 0s - loss: 371.4779
# Epoch 8/12
#  - 0s - loss: 337.6705
# Epoch 9/12
#  - 0s - loss: 305.7506
# Epoch 10/12
#  - 0s - loss: 276.7474
# Epoch 11/12
#  - 0s - loss: 250.7346
# Epoch 12/12
#  - 0s - loss: 226.3306

# %%
print(test_X.shape)
preds = clf.predict(test_X)
print(preds)
# Out:
# (203, 1, 13)
# [11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065  6.3539305 11.2611065
#  11.2611065 11.2611065 11.2611065  6.3539305 11.2611065 11.2611065
#  11.2611065 11.2611065  6.3539305 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065  6.3539305 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065  6.3539305 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#   6.3539305 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065  6.3539305 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#   6.3539305 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065  6.3539305 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.246108  11.2611065
#  11.2611065  6.3539305 11.2611065 11.2611065 11.2611065 11.2611065
#   6.3539305 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065  6.3539305 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065  6.3539305
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065 11.2611065
#  11.2611065 11.2611065 11.2611065 11.2611065 11.2611065]

# %% [markdown]
# # Generate SQL Code from the Model

# %%
import json, requests, base64, dill as pickle, sys



sys.setrecursionlimit(200000)
pickle.settings['recurse'] = False

# no luck for the web service... pickling feature of tensorflow and/or keras objects seems not to be a priority.
# there is a lot of github issues in the two projects when I search for pickle keyword!!!.

def test_ws_sql_gen(pickle_data):
    WS_URL="http://localhost:1888/model"
    b64_data = base64.b64encode(pickle_data).decode('utf-8')
    data={"Name":"model1", "PickleData":b64_data , "SQLDialect":"postgresql"}
    r = requests.post(WS_URL, json=data)
    print(r.__dict__)
    content = r.json()
    # print(content)
    lSQL = content["model"]["SQLGenrationResult"][0]["SQL"]
    return lSQL;



def test_sql_gen(keras_regressor , metadata):
    import sklearn2sql.PyCodeGenerator as codegen
    cg1 = codegen.cAbstractCodeGenerator();
    cg1.mOptions.mActivateMaterialization = False
    lSQL = cg1.generateCodeWithMetadata(clf, metadata, dsn = None, dialect = "postgresql");
    return lSQL[1]

# %%
# commented .. see above
# pickle_data = pickle.dumps(clf)
# lSQL = test_ws_sql_gen(pickle_data)
# print(lSQL[0:2000])

# %%
lMetaData = {}
lMetaData['features'] = list(boston.feature_names);
lMetaData["targets"] = ['TGT']
lMetaData['primary_key'] = 'KEY'
lMetaData['table'] = 'boston'

    
lSQL = test_sql_gen(clf , lMetaData)
# Out:
# cGenerationWrapperFactory::createWrapper() <class 'keras.wrappers.scikit_learn.KerasRegressor'>
# BACKEND_DIALECT postgresql
# CREATING_DATABASE_BACKEND_DSN_DIALECT 1.2.7 None postgresql
# KERAS_REG_GENERATE_EXPRESSION_START <class 'sqlalchemy.sql.selectable.Alias'> <class 'sklearn2sql.GenericModels.Keras.cSerializedKeras'>
# {'mKerasData': <keras.wrappers.scikit_learn.KerasRegressor object at 0x7f07d73244e0>, 'mFeatureNames': ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'], 'mClasses': None, 'mMode': 'Regression'}
# {'build_fn': <function create_model at 0x7f07d73172f0>, 'sk_params': {'batch_size': 1, 'epochs': 12, 'verbose': 2}, 'model': <keras.models.Sequential object at 0x7f07d73244a8>}
# ABSTRACT_GENERATE_CTE keras_input keras_input 14 False False
# ABSTRACT_GENERATE_SIMPLE_CTE keras_input 14
# GENERATING_LAYER 0 simple_rnn_1 <class 'keras.layers.recurrent.SimpleRNN'> {'input_spec': [InputSpec(shape=(1, None, 13), ndim=3)], 'supports_masking': True, 'stateful': True, '_trainable_weights': [], '_non_trainable_weights': [], '_losses': [], '_updates': [(<tf.Variable 'simple_rnn_1/Variable:0' shape=(1, 3) dtype=float32_ref>, <tf.Tensor 'simple_rnn_1/while/Exit_2:0' shape=(1, 3) dtype=float32>)], '_per_input_losses': {}, '_per_input_updates': {'139671651896680': [(<tf.Variable 'simple_rnn_1/Variable:0' shape=(1, 3) dtype=float32_ref>, <tf.Tensor 'simple_rnn_1/while/Exit_2:0' shape=(1, 3) dtype=float32>)]}, '_built': True, '_inbound_nodes': [<keras.engine.topology.Node object at 0x7f07d79bff60>], '_outbound_nodes': [<keras.engine.topology.Node object at 0x7f07cf245080>], 'name': 'simple_rnn_1', 'trainable': True, 'batch_input_shape': (1, 1, 13), 'dtype': 'float32', '_initial_weights': None, 'cell': <keras.layers.recurrent.SimpleRNNCell object at 0x7f07d7324668>, 'return_sequences': False, 'return_state': False, 'go_backwards': False, 'unroll': False, 'state_spec': [InputSpec(shape=(None, 3), ndim=2)], '_states': [<tf.Variable 'simple_rnn_1/Variable:0' shape=(1, 3) dtype=float32_ref>], 'constants_spec': None, '_num_constants': None, 'activity_regularizer': None}
# <class 'sqlalchemy.sql.selectable.CTE'>
# ABSTRACT_GENERATE_CTE keras_input keras_input_1 14 False False
# ABSTRACT_GENERATE_SIMPLE_CTE keras_input_1 14
# KERAS_GENERATE_LAYER_START <class 'keras.layers.recurrent.SimpleRNN'>
# KERAS_CREATE_LAYER_START <class 'keras.layers.recurrent.SimpleRNN'>
# cNN_Recurrent_LayerGenerator {'input_spec': [InputSpec(shape=(1, None, 13), ndim=3)], 'supports_masking': True, 'stateful': True, '_trainable_weights': [], '_non_trainable_weights': [], '_losses': [], '_updates': [(<tf.Variable 'simple_rnn_1/Variable:0' shape=(1, 3) dtype=float32_ref>, <tf.Tensor 'simple_rnn_1/while/Exit_2:0' shape=(1, 3) dtype=float32>)], '_per_input_losses': {}, '_per_input_updates': {'139671651896680': [(<tf.Variable 'simple_rnn_1/Variable:0' shape=(1, 3) dtype=float32_ref>, <tf.Tensor 'simple_rnn_1/while/Exit_2:0' shape=(1, 3) dtype=float32>)]}, '_built': True, '_inbound_nodes': [<keras.engine.topology.Node object at 0x7f07d79bff60>], '_outbound_nodes': [<keras.engine.topology.Node object at 0x7f07cf245080>], 'name': 'simple_rnn_1', 'trainable': True, 'batch_input_shape': (1, 1, 13), 'dtype': 'float32', '_initial_weights': None, 'cell': <keras.layers.recurrent.SimpleRNNCell object at 0x7f07d7324668>, 'return_sequences': False, 'return_state': False, 'go_backwards': False, 'unroll': False, 'state_spec': [InputSpec(shape=(None, 3), ndim=2)], '_states': [<tf.Variable 'simple_rnn_1/Variable:0' shape=(1, 3) dtype=float32_ref>], 'constants_spec': None, '_num_constants': None, 'activity_regularizer': None}
# ABSTRACT_GENERATE_CTE keras_input_1_rn keras_input_1_rn 15 False False
# ABSTRACT_GENERATE_SIMPLE_CTE keras_input_1_rn 15
# RN_CTE ([], <sqlalchemy.sql.selectable.CTE at 0x7f0809fa7b00; keras_input_1_rn>)
# SIMPLE_RNN_WEIGHTS 3 [(13, 3), (3, 3), (3,)] [array([[-0.07609601,  0.16619629, -0.0352487 ],
#        [-0.04115666,  0.09738326,  0.39412934],
#        [-0.16246578, -0.1880129 ,  0.20680875],
#        [ 0.11817126,  0.4437707 , -0.2002821 ],
#        [-0.2286192 , -0.49438074, -0.40995276],
#        [-0.49786916,  0.59409755, -0.4165488 ],
#        [ 0.26714715, -0.14400193, -0.5328968 ],
#        [-0.23344438,  0.5196392 ,  0.55201024],
#        [-0.37154487, -0.08744961, -0.57094467],
#        [ 0.13552316,  0.30870664, -0.22935629],
#        [-0.24440175,  0.25534827, -0.0009045 ],
#        [-0.40902826, -0.07319349, -0.3111218 ],
#        [-0.03639508,  0.3423996 ,  0.18181533]], dtype=float32), array([[-0.7419069 ,  0.02347285,  0.57230407],
#        [ 0.01605763, -0.9468123 ,  0.2759386 ],
#        [ 0.69782686,  0.32092923,  0.77222145]], dtype=float32), array([-0.15264748,  0.        ,  0.        ], dtype=float32)]
# ABSTRACT_GENERATE_CTE input_kernel_bias input_kernel_bias 18 False False
# ABSTRACT_GENERATE_SIMPLE_CTE input_kernel_bias 18
# ['input_kernel_bias.rn', 'input_kernel_bias.KEY', 'input_kernel_bias.CRIM', 'input_kernel_bias.ZN', 'input_kernel_bias.INDUS', 'input_kernel_bias.CHAS', 'input_kernel_bias.NOX', 'input_kernel_bias.RM', 'input_kernel_bias.AGE', 'input_kernel_bias.DIS', 'input_kernel_bias.RAD', 'input_kernel_bias.TAX', 'input_kernel_bias.PTRATIO', 'input_kernel_bias.B', 'input_kernel_bias.LSTAT', 'input_kernel_bias.dot_prod_1', 'input_kernel_bias.dot_prod_2', 'input_kernel_bias.dot_prod_3']
# RNN_LAYER_INTERNAL inputs  18 ['rn_1', 'KEY', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'dot_prod_1', 'dot_prod_2', 'dot_prod_3']
# RNN_LAYER_INTERNAL current_states  3 ['PreviousState_1', 'PreviousState_2', 'PreviousState_3']
# SIMPLE_RNN_WEIGHTS 3 [(13, 3), (3, 3), (3,)] [array([[-0.07609601,  0.16619629, -0.0352487 ],
#        [-0.04115666,  0.09738326,  0.39412934],
#        [-0.16246578, -0.1880129 ,  0.20680875],
#        [ 0.11817126,  0.4437707 , -0.2002821 ],
#        [-0.2286192 , -0.49438074, -0.40995276],
#        [-0.49786916,  0.59409755, -0.4165488 ],
#        [ 0.26714715, -0.14400193, -0.5328968 ],
#        [-0.23344438,  0.5196392 ,  0.55201024],
#        [-0.37154487, -0.08744961, -0.57094467],
#        [ 0.13552316,  0.30870664, -0.22935629],
#        [-0.24440175,  0.25534827, -0.0009045 ],
#        [-0.40902826, -0.07319349, -0.3111218 ],
#        [-0.03639508,  0.3423996 ,  0.18181533]], dtype=float32), array([[-0.7419069 ,  0.02347285,  0.57230407],
#        [ 0.01605763, -0.9468123 ,  0.2759386 ],
#        [ 0.69782686,  0.32092923,  0.77222145]], dtype=float32), array([-0.15264748,  0.        ,  0.        ], dtype=float32)]
# RECURRENT_LAYER_INTERNAL [<sqlalchemy.sql.elements.ColumnClause at 0x7f07c5e21a90; dot_prod_1>, <sqlalchemy.sql.elements.ColumnClause at 0x7f07c5e21ac8; dot_prod_2>, <sqlalchemy.sql.elements.ColumnClause at 0x7f07c5e21b00; dot_prod_3>]
# RECURRENT_LAYER_FINAL [<sqlalchemy.sql.elements.Label object at 0x7f07c5db3438>, <sqlalchemy.sql.elements.Label object at 0x7f07c5db39b0>, <sqlalchemy.sql.elements.Label object at 0x7f07c5e21e48>]
# GENERATE_ACTIVATION_FUNCTION_ONE_COLUMN tanh output_1
# GENERATE_ACTIVATION_FUNCTION_ONE_COLUMN tanh output_2
# GENERATE_ACTIVATION_FUNCTION_ONE_COLUMN tanh output_3
# RNN_LAYER_INTERNAL inputs  18 ['rn', 'KEY', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'dot_prod_1', 'dot_prod_2', 'dot_prod_3']
# RNN_LAYER_INTERNAL current_states  3 ['PreviousState_1', 'PreviousState_2', 'PreviousState_3']
# SIMPLE_RNN_WEIGHTS 3 [(13, 3), (3, 3), (3,)] [array([[-0.07609601,  0.16619629, -0.0352487 ],
#        [-0.04115666,  0.09738326,  0.39412934],
#        [-0.16246578, -0.1880129 ,  0.20680875],
#        [ 0.11817126,  0.4437707 , -0.2002821 ],
#        [-0.2286192 , -0.49438074, -0.40995276],
#        [-0.49786916,  0.59409755, -0.4165488 ],
#        [ 0.26714715, -0.14400193, -0.5328968 ],
#        [-0.23344438,  0.5196392 ,  0.55201024],
#        [-0.37154487, -0.08744961, -0.57094467],
#        [ 0.13552316,  0.30870664, -0.22935629],
#        [-0.24440175,  0.25534827, -0.0009045 ],
#        [-0.40902826, -0.07319349, -0.3111218 ],
#        [-0.03639508,  0.3423996 ,  0.18181533]], dtype=float32), array([[-0.7419069 ,  0.02347285,  0.57230407],
#        [ 0.01605763, -0.9468123 ,  0.2759386 ],
#        [ 0.69782686,  0.32092923,  0.77222145]], dtype=float32), array([-0.15264748,  0.        ,  0.        ], dtype=float32)]
# RECURRENT_LAYER_INTERNAL [<sqlalchemy.sql.elements.ColumnClause at 0x7f07c5e21a90; dot_prod_1>, <sqlalchemy.sql.elements.ColumnClause at 0x7f07c5e21ac8; dot_prod_2>, <sqlalchemy.sql.elements.ColumnClause at 0x7f07c5e21b00; dot_prod_3>]
# RECURRENT_LAYER_FINAL [<sqlalchemy.sql.elements.Label object at 0x7f07c5dc95f8>, <sqlalchemy.sql.elements.Label object at 0x7f07c5dc9b38>, <sqlalchemy.sql.elements.Label object at 0x7f07c5dc9eb8>]
# GENERATE_ACTIVATION_FUNCTION_ONE_COLUMN tanh output_1
# GENERATE_ACTIVATION_FUNCTION_ONE_COLUMN tanh output_2
# GENERATE_ACTIVATION_FUNCTION_ONE_COLUMN tanh output_3
# WITH RECURSIVE keras_input AS
# (SELECT "ADS"."KEY" AS "KEY", "ADS"."CRIM" AS "CRIM", "ADS"."ZN" AS "ZN", "ADS"."INDUS" AS "INDUS", "ADS"."CHAS" AS "CHAS", "ADS"."NOX" AS "NOX", "ADS"."RM" AS "RM", "ADS"."AGE" AS "AGE", "ADS"."DIS" AS "DIS", "ADS"."RAD" AS "RAD", "ADS"."TAX" AS "TAX", "ADS"."PTRATIO" AS "PTRATIO", "ADS"."B" AS "B", "ADS"."LSTAT" AS "LSTAT"
# FROM boston AS "ADS"),
# keras_input_1 AS
# (SELECT keras_input."KEY" AS "KEY", keras_input."CRIM" AS "CRIM", keras_input."ZN" AS "ZN", keras_input."INDUS" AS "INDUS", keras_input."CHAS" AS "CHAS", keras_input."NOX" AS "NOX", keras_input."RM" AS "RM", keras_input."AGE" AS "AGE", keras_input."DIS" AS "DIS", keras_input."RAD" AS "RAD", keras_input."TAX" AS "TAX", keras_input."PTRATIO" AS "PTRATIO", keras_input."B" AS "B", keras_input."LSTAT" AS "LSTAT"
# FROM keras_input),
# keras_input_1_rn AS
# (SELECT row_number() OVER (ORDER BY keras_input_1."KEY" ASC) AS rn, keras_input_1."KEY" AS "KEY", keras_input_1."CRIM" AS "CRIM", keras_input_1."ZN" AS "ZN", keras_input_1."INDUS" AS "INDUS", keras_input_1."CHAS" AS "CHAS", keras_input_1."NOX" AS "NOX", keras_input_1."RM" AS "RM", keras_input_1."AGE" AS "AGE", keras_input_1."DIS" AS "DIS", keras_input_1."RAD" AS "RAD", keras_input_1."TAX" AS "TAX", keras_input_1."PTRATIO" AS "PTRATIO", keras_input_1."B" AS "B", keras_input_1."LSTAT" AS "LSTAT"
# FROM keras_input_1),
# input_kernel_bias AS
# (SELECT keras_input_1_rn.rn AS rn, keras_input_1_rn."KEY" AS "KEY", keras_input_1_rn."CRIM" AS "CRIM", keras_input_1_rn."ZN" AS "ZN", keras_input_1_rn."INDUS" AS "INDUS", keras_input_1_rn."CHAS" AS "CHAS", keras_input_1_rn."NOX" AS "NOX", keras_input_1_rn."RM" AS "RM", keras_input_1_rn."AGE" AS "AGE", keras_input_1_rn."DIS" AS "DIS", keras_input_1_rn."RAD" AS "RAD", keras_input_1_rn."TAX" AS "TAX", keras_input_1_rn."PTRATIO" AS "PTRATIO", keras_input_1_rn."B" AS "B", keras_input_1_rn."LSTAT" AS "LSTAT", :param_13 + :param_14 * keras_input_1_rn."CRIM" + :param_15 * keras_input_1_rn."ZN" + :param_16 * keras_input_1_rn."INDUS" + :param_17 * keras_input_1_rn."CHAS" + :param_18 * keras_input_1_rn."NOX" + :param_19 * keras_input_1_rn."RM" + :param_20 * keras_input_1_rn."AGE" + :param_21 * keras_input_1_rn."DIS" + :param_22 * keras_input_1_rn."RAD" + :param_23 * keras_input_1_rn."TAX" + :param_24 * keras_input_1_rn."PTRATIO" + :param_25 * keras_input_1_rn."B" + :param_26 * keras_input_1_rn."LSTAT" AS dot_prod_1, :param_27 + :param_28 * keras_input_1_rn."CRIM" + :param_29 * keras_input_1_rn."ZN" + :param_30 * keras_input_1_rn."INDUS" + :param_31 * keras_input_1_rn."CHAS" + :param_32 * keras_input_1_rn."NOX" + :param_33 * keras_input_1_rn."RM" + :param_34 * keras_input_1_rn."AGE" + :param_35 * keras_input_1_rn."DIS" + :param_36 * keras_input_1_rn."RAD" + :param_37 * keras_input_1_rn."TAX" + :param_38 * keras_input_1_rn."PTRATIO" + :param_39 * keras_input_1_rn."B" + :param_40 * keras_input_1_rn."LSTAT" AS dot_prod_2, :param_41 + :param_42 * keras_input_1_rn."CRIM" + :param_43 * keras_input_1_rn."ZN" + :param_44 * keras_input_1_rn."INDUS" + :param_45 * keras_input_1_rn."CHAS" + :param_46 * keras_input_1_rn."NOX" + :param_47 * keras_input_1_rn."RM" + :param_48 * keras_input_1_rn."AGE" + :param_49 * keras_input_1_rn."DIS" + :param_50 * keras_input_1_rn."RAD" + :param_51 * keras_input_1_rn."TAX" + :param_52 * keras_input_1_rn."PTRATIO" + :param_53 * keras_input_1_rn."B" + :param_54 * keras_input_1_rn."LSTAT" AS dot_prod_3
# FROM keras_input_1_rn),
# rnn_cte_simple_rnn_1(rn_1, "KEY", "PreviousState_1", "PreviousState_2", "PreviousState_3", output_1, output_2, output_3, "State_1", "State_2", "State_3") AS
# (SELECT input_kernel_bias.rn AS rn_1, input_kernel_bias."KEY" AS "KEY", CAST(:param_1 AS FLOAT) AS "PreviousState_1", CAST(:param_2 AS FLOAT) AS "PreviousState_2", CAST(:param_3 AS FLOAT) AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3) - exp(-(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3))) / (exp(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3) + exp(-(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3) - exp(-(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3))) / (exp(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3) + exp(-(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3) - exp(-(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3))) / (exp(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3) + exp(-(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3) - exp(-(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3))) / (exp(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3) + exp(-(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3) - exp(-(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3))) / (exp(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3) + exp(-(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3))) AS "State_2", (exp(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3) - exp(-(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3))) / (exp(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3) + exp(-(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3))) AS "State_3"
# FROM input_kernel_bias
# WHERE input_kernel_bias.rn = :rn_1 UNION ALL SELECT input_kernel_bias.rn AS rn, input_kernel_bias."KEY" AS "KEY", rnn_cte_simple_rnn_1."State_1" AS "PreviousState_1", rnn_cte_simple_rnn_1."State_2" AS "PreviousState_2", rnn_cte_simple_rnn_1."State_3" AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3"))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3"))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3"))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3"))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3"))) AS "State_2", (exp(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_ ...
# FROM input_kernel_bias, rnn_cte_simple_rnn_1
# WHERE input_kernel_bias.rn = rnn_cte_simple_rnn_1.rn_1 + :param_64)
#  SELECT rnn_cte_simple_rnn_1.rn_1, rnn_cte_simple_rnn_1."KEY", rnn_cte_simple_rnn_1."PreviousState_1", rnn_cte_simple_rnn_1."PreviousState_2", rnn_cte_simple_rnn_1."PreviousState_3", rnn_cte_simple_rnn_1.output_1, rnn_cte_simple_rnn_1.output_2, rnn_cte_simple_rnn_1.output_3, rnn_cte_simple_rnn_1."State_1", rnn_cte_simple_rnn_1."State_2", rnn_cte_simple_rnn_1."State_3"
# FROM rnn_cte_simple_rnn_1
# ABSTRACT_GENERATE_CTE simple_rnn_1 simple_rnn_1 4 False False
# ABSTRACT_GENERATE_SIMPLE_CTE simple_rnn_1 4
# ['simple_rnn_1.KEY', 'simple_rnn_1.output_1', 'simple_rnn_1.output_2', 'simple_rnn_1.output_3']
# WITH RECURSIVE keras_input AS
# (SELECT "ADS"."KEY" AS "KEY", "ADS"."CRIM" AS "CRIM", "ADS"."ZN" AS "ZN", "ADS"."INDUS" AS "INDUS", "ADS"."CHAS" AS "CHAS", "ADS"."NOX" AS "NOX", "ADS"."RM" AS "RM", "ADS"."AGE" AS "AGE", "ADS"."DIS" AS "DIS", "ADS"."RAD" AS "RAD", "ADS"."TAX" AS "TAX", "ADS"."PTRATIO" AS "PTRATIO", "ADS"."B" AS "B", "ADS"."LSTAT" AS "LSTAT"
# FROM boston AS "ADS"),
# keras_input_1 AS
# (SELECT keras_input."KEY" AS "KEY", keras_input."CRIM" AS "CRIM", keras_input."ZN" AS "ZN", keras_input."INDUS" AS "INDUS", keras_input."CHAS" AS "CHAS", keras_input."NOX" AS "NOX", keras_input."RM" AS "RM", keras_input."AGE" AS "AGE", keras_input."DIS" AS "DIS", keras_input."RAD" AS "RAD", keras_input."TAX" AS "TAX", keras_input."PTRATIO" AS "PTRATIO", keras_input."B" AS "B", keras_input."LSTAT" AS "LSTAT"
# FROM keras_input),
# keras_input_1_rn AS
# (SELECT row_number() OVER (ORDER BY keras_input_1."KEY" ASC) AS rn, keras_input_1."KEY" AS "KEY", keras_input_1."CRIM" AS "CRIM", keras_input_1."ZN" AS "ZN", keras_input_1."INDUS" AS "INDUS", keras_input_1."CHAS" AS "CHAS", keras_input_1."NOX" AS "NOX", keras_input_1."RM" AS "RM", keras_input_1."AGE" AS "AGE", keras_input_1."DIS" AS "DIS", keras_input_1."RAD" AS "RAD", keras_input_1."TAX" AS "TAX", keras_input_1."PTRATIO" AS "PTRATIO", keras_input_1."B" AS "B", keras_input_1."LSTAT" AS "LSTAT"
# FROM keras_input_1),
# input_kernel_bias AS
# (SELECT keras_input_1_rn.rn AS rn, keras_input_1_rn."KEY" AS "KEY", keras_input_1_rn."CRIM" AS "CRIM", keras_input_1_rn."ZN" AS "ZN", keras_input_1_rn."INDUS" AS "INDUS", keras_input_1_rn."CHAS" AS "CHAS", keras_input_1_rn."NOX" AS "NOX", keras_input_1_rn."RM" AS "RM", keras_input_1_rn."AGE" AS "AGE", keras_input_1_rn."DIS" AS "DIS", keras_input_1_rn."RAD" AS "RAD", keras_input_1_rn."TAX" AS "TAX", keras_input_1_rn."PTRATIO" AS "PTRATIO", keras_input_1_rn."B" AS "B", keras_input_1_rn."LSTAT" AS "LSTAT", :param_13 + :param_14 * keras_input_1_rn."CRIM" + :param_15 * keras_input_1_rn."ZN" + :param_16 * keras_input_1_rn."INDUS" + :param_17 * keras_input_1_rn."CHAS" + :param_18 * keras_input_1_rn."NOX" + :param_19 * keras_input_1_rn."RM" + :param_20 * keras_input_1_rn."AGE" + :param_21 * keras_input_1_rn."DIS" + :param_22 * keras_input_1_rn."RAD" + :param_23 * keras_input_1_rn."TAX" + :param_24 * keras_input_1_rn."PTRATIO" + :param_25 * keras_input_1_rn."B" + :param_26 * keras_input_1_rn."LSTAT" AS dot_prod_1, :param_27 + :param_28 * keras_input_1_rn."CRIM" + :param_29 * keras_input_1_rn."ZN" + :param_30 * keras_input_1_rn."INDUS" + :param_31 * keras_input_1_rn."CHAS" + :param_32 * keras_input_1_rn."NOX" + :param_33 * keras_input_1_rn."RM" + :param_34 * keras_input_1_rn."AGE" + :param_35 * keras_input_1_rn."DIS" + :param_36 * keras_input_1_rn."RAD" + :param_37 * keras_input_1_rn."TAX" + :param_38 * keras_input_1_rn."PTRATIO" + :param_39 * keras_input_1_rn."B" + :param_40 * keras_input_1_rn."LSTAT" AS dot_prod_2, :param_41 + :param_42 * keras_input_1_rn."CRIM" + :param_43 * keras_input_1_rn."ZN" + :param_44 * keras_input_1_rn."INDUS" + :param_45 * keras_input_1_rn."CHAS" + :param_46 * keras_input_1_rn."NOX" + :param_47 * keras_input_1_rn."RM" + :param_48 * keras_input_1_rn."AGE" + :param_49 * keras_input_1_rn."DIS" + :param_50 * keras_input_1_rn."RAD" + :param_51 * keras_input_1_rn."TAX" + :param_52 * keras_input_1_rn."PTRATIO" + :param_53 * keras_input_1_rn."B" + :param_54 * keras_input_1_rn."LSTAT" AS dot_prod_3
# FROM keras_input_1_rn),
# rnn_cte_simple_rnn_1(rn_1, "KEY", "PreviousState_1", "PreviousState_2", "PreviousState_3", output_1, output_2, output_3, "State_1", "State_2", "State_3") AS
# (SELECT input_kernel_bias.rn AS rn_1, input_kernel_bias."KEY" AS "KEY", CAST(:param_1 AS FLOAT) AS "PreviousState_1", CAST(:param_2 AS FLOAT) AS "PreviousState_2", CAST(:param_3 AS FLOAT) AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3) - exp(-(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3))) / (exp(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3) + exp(-(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3) - exp(-(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3))) / (exp(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3) + exp(-(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3) - exp(-(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3))) / (exp(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3) + exp(-(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3) - exp(-(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3))) / (exp(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3) + exp(-(input_kernel_bias.dot_prod_1 + :param_4 * :param_1 + :param_5 * :param_2 + :param_6 * :param_3))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3) - exp(-(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3))) / (exp(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3) + exp(-(input_kernel_bias.dot_prod_2 + :param_7 * :param_1 + :param_8 * :param_2 + :param_9 * :param_3))) AS "State_2", (exp(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3) - exp(-(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3))) / (exp(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3) + exp(-(input_kernel_bias.dot_prod_3 + :param_10 * :param_1 + :param_11 * :param_2 + :param_12 * :param_3))) AS "State_3"
# FROM input_kernel_bias
# WHERE input_kernel_bias.rn = :rn_1 UNION ALL SELECT input_kernel_bias.rn AS rn, input_kernel_bias."KEY" AS "KEY", rnn_cte_simple_rnn_1."State_1" AS "PreviousState_1", rnn_cte_simple_rnn_1."State_2" AS "PreviousState_2", rnn_cte_simple_rnn_1."State_3" AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3"))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3"))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3"))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + :param_55 * rnn_cte_simple_rnn_1."State_1" + :param_56 * rnn_cte_simple_rnn_1."State_2" + :param_57 * rnn_cte_simple_rnn_1."State_3"))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_2 + :param_58 * rnn_cte_simple_rnn_1."State_1" + :param_59 * rnn_cte_simple_rnn_1."State_2" + :param_60 * rnn_cte_simple_rnn_1."State_3"))) AS "State_2", (exp(input_kernel_bias.dot_prod_3 + :param_61 * rnn_cte_simple_rnn_1."State_1" + :param_62 * rnn_cte_simple_rnn_1."State_2" + :param_63 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_ ...
# FROM input_kernel_bias, rnn_cte_simple_rnn_1
# WHERE input_kernel_bias.rn = rnn_cte_simple_rnn_1.rn_1 + :param_64),
# simple_rnn_1 AS
# (SELECT rnn_cte_simple_rnn_1."KEY" AS "KEY", CAST(rnn_cte_simple_rnn_1.output_1 AS FLOAT) AS output_1, CAST(rnn_cte_simple_rnn_1.output_2 AS FLOAT) AS output_2, CAST(rnn_cte_simple_rnn_1.output_3 AS FLOAT) AS output_3
# FROM rnn_cte_simple_rnn_1)
#  SELECT simple_rnn_1."KEY", simple_rnn_1.output_1, simple_rnn_1.output_2, simple_rnn_1.output_3
# FROM simple_rnn_1
# doGenerateCode_CTE simple_rnn_1
# doGenerateCode_TEMP simple_rnn_1 []
# GENERATING_LAYER 1 dense_1 <class 'keras.layers.core.Dense'> {'input_spec': InputSpec(min_ndim=2, axes={-1: 3}), 'supports_masking': True, 'stateful': False, '_trainable_weights': [<tf.Variable 'dense_1/kernel:0' shape=(3, 1) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32_ref>], '_non_trainable_weights': [], '_losses': [], '_updates': [], '_per_input_losses': {}, '_per_input_updates': {}, '_built': True, '_inbound_nodes': [<keras.engine.topology.Node object at 0x7f07cf245080>], '_outbound_nodes': [], 'name': 'dense_1', 'trainable': True, '_initial_weights': None, 'units': 1, 'activation': <function linear at 0x7f07e064c840>, 'use_bias': True, 'kernel_initializer': <keras.initializers.VarianceScaling object at 0x7f07cf2a9710>, 'bias_initializer': <keras.initializers.Zeros object at 0x7f07cf264c88>, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'kernel': <tf.Variable 'dense_1/kernel:0' shape=(3, 1) dtype=float32_ref>, 'bias': <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32_ref>}
# <class 'sqlalchemy.sql.selectable.CTE'>
# ABSTRACT_GENERATE_CTE simple_rnn_1 simple_rnn_1_1 4 False False
# ABSTRACT_GENERATE_SIMPLE_CTE simple_rnn_1_1 4
# KERAS_GENERATE_LAYER_START <class 'keras.layers.core.Dense'>
# KERAS_CREATE_LAYER_START <class 'keras.layers.core.Dense'>
# ABSTRACT_GENERATE_CTE layer_dense_1 layer_dense_1 2 False False
# ABSTRACT_GENERATE_SIMPLE_CTE layer_dense_1 2
# doGenerateCode_CTE dense_1
# doGenerateCode_TEMP dense_1 []
# GENERATE_ACTIVATION_FUNCTION linear
# KERAS_REG_CODE_GENERATION_END <class 'sqlalchemy.sql.selectable.Alias'> <class 'sklearn2sql.GenericModels.Keras.cSerializedKeras'>
# DUMP_RESULT_CLASSES : []
# DUMP_RESULT_KEY_EXPRESSIONS : ['KEY']
# DUMP_RESULT_DECISION_EXPRESSION : None
# DUMP_RESULT_DECISION_PROBABILITY_EXPRESSION : None
# DUMP_RESULT_REG_EXPRESSIONS : {'Estimator': <sqlalchemy.sql.elements.Label object at 0x7f07c5d8efd0>}
# DUMP_RESULT_FEATURE_EXPRESSIONS : 0
# DUMP_TEMP_TABLES : []
# TEMP_SQLS []
# FINAL_SQL WITH RECURSIVE keras_input AS
# (SELECT "ADS"."KEY" AS "KEY", "ADS"."CRIM" AS "CRIM", "ADS"."ZN" AS "ZN", "ADS"."INDUS" AS "INDUS", "ADS"."CHAS" AS "CHAS", "ADS"."NOX" AS "NOX", "ADS"."RM" AS "RM", "ADS"."AGE" AS "AGE", "ADS"."DIS" AS "DIS", "ADS"."RAD" AS "RAD", "ADS"."TAX" AS "TAX", "ADS"."PTRATIO" AS "PTRATIO", "ADS"."B" AS "B", "ADS"."LSTAT" AS "LSTAT"
# FROM boston AS "ADS"),
# keras_input_1 AS
# (SELECT keras_input."KEY" AS "KEY", keras_input."CRIM" AS "CRIM", keras_input."ZN" AS "ZN", keras_input."INDUS" AS "INDUS", keras_input."CHAS" AS "CHAS", keras_input."NOX" AS "NOX", keras_input."RM" AS "RM", keras_input."AGE" AS "AGE", keras_input."DIS" AS "DIS", keras_input."RAD" AS "RAD", keras_input."TAX" AS "TAX", keras_input."PTRATIO" AS "PTRATIO", keras_input."B" AS "B", keras_input."LSTAT" AS "LSTAT"
# FROM keras_input),
# keras_input_1_rn AS
# (SELECT row_number() OVER (ORDER BY keras_input_1."KEY" ASC) AS rn, keras_input_1."KEY" AS "KEY", keras_input_1."CRIM" AS "CRIM", keras_input_1."ZN" AS "ZN", keras_input_1."INDUS" AS "INDUS", keras_input_1."CHAS" AS "CHAS", keras_input_1."NOX" AS "NOX", keras_input_1."RM" AS "RM", keras_input_1."AGE" AS "AGE", keras_input_1."DIS" AS "DIS", keras_input_1."RAD" AS "RAD", keras_input_1."TAX" AS "TAX", keras_input_1."PTRATIO" AS "PTRATIO", keras_input_1."B" AS "B", keras_input_1."LSTAT" AS "LSTAT"
# FROM keras_input_1),
# input_kernel_bias AS
# (SELECT keras_input_1_rn.rn AS rn, keras_input_1_rn."KEY" AS "KEY", keras_input_1_rn."CRIM" AS "CRIM", keras_input_1_rn."ZN" AS "ZN", keras_input_1_rn."INDUS" AS "INDUS", keras_input_1_rn."CHAS" AS "CHAS", keras_input_1_rn."NOX" AS "NOX", keras_input_1_rn."RM" AS "RM", keras_input_1_rn."AGE" AS "AGE", keras_input_1_rn."DIS" AS "DIS", keras_input_1_rn."RAD" AS "RAD", keras_input_1_rn."TAX" AS "TAX", keras_input_1_rn."PTRATIO" AS "PTRATIO", keras_input_1_rn."B" AS "B", keras_input_1_rn."LSTAT" AS "LSTAT", -0.1526474803686142 + -0.07609600573778152 * keras_input_1_rn."CRIM" + -0.04115665704011917 * keras_input_1_rn."ZN" + -0.16246578097343445 * keras_input_1_rn."INDUS" + 0.11817125976085663 * keras_input_1_rn."CHAS" + -0.22861920297145844 * keras_input_1_rn."NOX" + -0.4978691637516022 * keras_input_1_rn."RM" + 0.26714715361595154 * keras_input_1_rn."AGE" + -0.23344437777996063 * keras_input_1_rn."DIS" + -0.37154486775398254 * keras_input_1_rn."RAD" + 0.13552315533161163 * keras_input_1_rn."TAX" + -0.244401752948761 * keras_input_1_rn."PTRATIO" + -0.4090282618999481 * keras_input_1_rn."B" + -0.036395084112882614 * keras_input_1_rn."LSTAT" AS dot_prod_1, 0.0 + 0.1661962866783142 * keras_input_1_rn."CRIM" + 0.09738326072692871 * keras_input_1_rn."ZN" + -0.18801289796829224 * keras_input_1_rn."INDUS" + 0.44377070665359497 * keras_input_1_rn."CHAS" + -0.49438074231147766 * keras_input_1_rn."NOX" + 0.5940975546836853 * keras_input_1_rn."RM" + -0.14400193095207214 * keras_input_1_rn."AGE" + 0.5196391940116882 * keras_input_1_rn."DIS" + -0.08744961023330688 * keras_input_1_rn."RAD" + 0.3087066411972046 * keras_input_1_rn."TAX" + 0.255348265171051 * keras_input_1_rn."PTRATIO" + -0.0731934905052185 * keras_input_1_rn."B" + 0.34239959716796875 * keras_input_1_rn."LSTAT" AS dot_prod_2, 0.0 + -0.03524869680404663 * keras_input_1_rn."CRIM" + 0.39412933588027954 * keras_input_1_rn."ZN" + 0.20680874586105347 * keras_input_1_rn."INDUS" + -0.20028209686279297 * keras_input_1_rn."CHAS" + -0.4099527597427368 * keras_input_1_rn."NOX" + -0.41654878854751587 * keras_input_1_rn."RM" + -0.5328968167304993 * keras_input_1_rn."AGE" + 0.5520102381706238 * keras_input_1_rn."DIS" + -0.5709446668624878 * keras_input_1_rn."RAD" + -0.2293562889099121 * keras_input_1_rn."TAX" + -0.0009045004844665527 * keras_input_1_rn."PTRATIO" + -0.31112179160118103 * keras_input_1_rn."B" + 0.18181532621383667 * keras_input_1_rn."LSTAT" AS dot_prod_3
# FROM keras_input_1_rn),
# rnn_cte_simple_rnn_1(rn_1, "KEY", "PreviousState_1", "PreviousState_2", "PreviousState_3", output_1, output_2, output_3, "State_1", "State_2", "State_3") AS
# (SELECT input_kernel_bias.rn AS rn_1, input_kernel_bias."KEY" AS "KEY", CAST(0.0 AS FLOAT) AS "PreviousState_1", CAST(0.0 AS FLOAT) AS "PreviousState_2", CAST(0.0 AS FLOAT) AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) AS "State_2", (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) AS "State_3"
# FROM input_kernel_bias
# WHERE input_kernel_bias.rn = 1 UNION ALL SELECT input_kernel_bias.rn AS rn, input_kernel_bias."KEY" AS "KEY", rnn_cte_simple_rnn_1."State_1" AS "PreviousState_1", rnn_cte_simple_rnn_1."State_2" AS "PreviousState_2", rnn_cte_simple_rnn_1."State_3" AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3"))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.do ...
# FROM input_kernel_bias, rnn_cte_simple_rnn_1
# WHERE input_kernel_bias.rn = rnn_cte_simple_rnn_1.rn_1 + 1),
# simple_rnn_1 AS
# (SELECT rnn_cte_simple_rnn_1."KEY" AS "KEY", CAST(rnn_cte_simple_rnn_1.output_1 AS FLOAT) AS output_1, CAST(rnn_cte_simple_rnn_1.output_2 AS FLOAT) AS output_2, CAST(rnn_cte_simple_rnn_1.output_3 AS FLOAT) AS output_3
# FROM rnn_cte_simple_rnn_1),
# simple_rnn_1_1 AS
# (SELECT simple_rnn_1."KEY" AS "KEY", simple_rnn_1.output_1 AS output_1, simple_rnn_1.output_2 AS output_2, simple_rnn_1.output_3 AS output_3
# FROM simple_rnn_1),
# layer_dense_1 AS
# (SELECT simple_rnn_1_1."KEY" AS "KEY", 3.2233598232269287 + -2.453587770462036 * simple_rnn_1_1.output_1 + 3.02994966506958 * simple_rnn_1_1.output_2 + -2.554208755493164 * simple_rnn_1_1.output_3 AS output_1
# FROM simple_rnn_1_1)
#  SELECT layer_dense_1."KEY" AS "KEY", layer_dense_1.output_1 AS "Estimator"
# FROM layer_dense_1

# %%
print(lSQL)
# Out:
# WITH RECURSIVE keras_input AS
# (SELECT "ADS"."KEY" AS "KEY", "ADS"."CRIM" AS "CRIM", "ADS"."ZN" AS "ZN", "ADS"."INDUS" AS "INDUS", "ADS"."CHAS" AS "CHAS", "ADS"."NOX" AS "NOX", "ADS"."RM" AS "RM", "ADS"."AGE" AS "AGE", "ADS"."DIS" AS "DIS", "ADS"."RAD" AS "RAD", "ADS"."TAX" AS "TAX", "ADS"."PTRATIO" AS "PTRATIO", "ADS"."B" AS "B", "ADS"."LSTAT" AS "LSTAT"
# FROM boston AS "ADS"),
# keras_input_1 AS
# (SELECT keras_input."KEY" AS "KEY", keras_input."CRIM" AS "CRIM", keras_input."ZN" AS "ZN", keras_input."INDUS" AS "INDUS", keras_input."CHAS" AS "CHAS", keras_input."NOX" AS "NOX", keras_input."RM" AS "RM", keras_input."AGE" AS "AGE", keras_input."DIS" AS "DIS", keras_input."RAD" AS "RAD", keras_input."TAX" AS "TAX", keras_input."PTRATIO" AS "PTRATIO", keras_input."B" AS "B", keras_input."LSTAT" AS "LSTAT"
# FROM keras_input),
# keras_input_1_rn AS
# (SELECT row_number() OVER (ORDER BY keras_input_1."KEY" ASC) AS rn, keras_input_1."KEY" AS "KEY", keras_input_1."CRIM" AS "CRIM", keras_input_1."ZN" AS "ZN", keras_input_1."INDUS" AS "INDUS", keras_input_1."CHAS" AS "CHAS", keras_input_1."NOX" AS "NOX", keras_input_1."RM" AS "RM", keras_input_1."AGE" AS "AGE", keras_input_1."DIS" AS "DIS", keras_input_1."RAD" AS "RAD", keras_input_1."TAX" AS "TAX", keras_input_1."PTRATIO" AS "PTRATIO", keras_input_1."B" AS "B", keras_input_1."LSTAT" AS "LSTAT"
# FROM keras_input_1),
# input_kernel_bias AS
# (SELECT keras_input_1_rn.rn AS rn, keras_input_1_rn."KEY" AS "KEY", keras_input_1_rn."CRIM" AS "CRIM", keras_input_1_rn."ZN" AS "ZN", keras_input_1_rn."INDUS" AS "INDUS", keras_input_1_rn."CHAS" AS "CHAS", keras_input_1_rn."NOX" AS "NOX", keras_input_1_rn."RM" AS "RM", keras_input_1_rn."AGE" AS "AGE", keras_input_1_rn."DIS" AS "DIS", keras_input_1_rn."RAD" AS "RAD", keras_input_1_rn."TAX" AS "TAX", keras_input_1_rn."PTRATIO" AS "PTRATIO", keras_input_1_rn."B" AS "B", keras_input_1_rn."LSTAT" AS "LSTAT", -0.1526474803686142 + -0.07609600573778152 * keras_input_1_rn."CRIM" + -0.04115665704011917 * keras_input_1_rn."ZN" + -0.16246578097343445 * keras_input_1_rn."INDUS" + 0.11817125976085663 * keras_input_1_rn."CHAS" + -0.22861920297145844 * keras_input_1_rn."NOX" + -0.4978691637516022 * keras_input_1_rn."RM" + 0.26714715361595154 * keras_input_1_rn."AGE" + -0.23344437777996063 * keras_input_1_rn."DIS" + -0.37154486775398254 * keras_input_1_rn."RAD" + 0.13552315533161163 * keras_input_1_rn."TAX" + -0.244401752948761 * keras_input_1_rn."PTRATIO" + -0.4090282618999481 * keras_input_1_rn."B" + -0.036395084112882614 * keras_input_1_rn."LSTAT" AS dot_prod_1, 0.0 + 0.1661962866783142 * keras_input_1_rn."CRIM" + 0.09738326072692871 * keras_input_1_rn."ZN" + -0.18801289796829224 * keras_input_1_rn."INDUS" + 0.44377070665359497 * keras_input_1_rn."CHAS" + -0.49438074231147766 * keras_input_1_rn."NOX" + 0.5940975546836853 * keras_input_1_rn."RM" + -0.14400193095207214 * keras_input_1_rn."AGE" + 0.5196391940116882 * keras_input_1_rn."DIS" + -0.08744961023330688 * keras_input_1_rn."RAD" + 0.3087066411972046 * keras_input_1_rn."TAX" + 0.255348265171051 * keras_input_1_rn."PTRATIO" + -0.0731934905052185 * keras_input_1_rn."B" + 0.34239959716796875 * keras_input_1_rn."LSTAT" AS dot_prod_2, 0.0 + -0.03524869680404663 * keras_input_1_rn."CRIM" + 0.39412933588027954 * keras_input_1_rn."ZN" + 0.20680874586105347 * keras_input_1_rn."INDUS" + -0.20028209686279297 * keras_input_1_rn."CHAS" + -0.4099527597427368 * keras_input_1_rn."NOX" + -0.41654878854751587 * keras_input_1_rn."RM" + -0.5328968167304993 * keras_input_1_rn."AGE" + 0.5520102381706238 * keras_input_1_rn."DIS" + -0.5709446668624878 * keras_input_1_rn."RAD" + -0.2293562889099121 * keras_input_1_rn."TAX" + -0.0009045004844665527 * keras_input_1_rn."PTRATIO" + -0.31112179160118103 * keras_input_1_rn."B" + 0.18181532621383667 * keras_input_1_rn."LSTAT" AS dot_prod_3
# FROM keras_input_1_rn),
# rnn_cte_simple_rnn_1(rn_1, "KEY", "PreviousState_1", "PreviousState_2", "PreviousState_3", output_1, output_2, output_3, "State_1", "State_2", "State_3") AS
# (SELECT input_kernel_bias.rn AS rn_1, input_kernel_bias."KEY" AS "KEY", CAST(0.0 AS FLOAT) AS "PreviousState_1", CAST(0.0 AS FLOAT) AS "PreviousState_2", CAST(0.0 AS FLOAT) AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) AS "State_2", (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) AS "State_3"
# FROM input_kernel_bias
# WHERE input_kernel_bias.rn = 1 UNION ALL SELECT input_kernel_bias.rn AS rn, input_kernel_bias."KEY" AS "KEY", rnn_cte_simple_rnn_1."State_1" AS "PreviousState_1", rnn_cte_simple_rnn_1."State_2" AS "PreviousState_2", rnn_cte_simple_rnn_1."State_3" AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3"))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.do ...
# FROM input_kernel_bias, rnn_cte_simple_rnn_1
# WHERE input_kernel_bias.rn = rnn_cte_simple_rnn_1.rn_1 + 1),
# simple_rnn_1 AS
# (SELECT rnn_cte_simple_rnn_1."KEY" AS "KEY", CAST(rnn_cte_simple_rnn_1.output_1 AS FLOAT) AS output_1, CAST(rnn_cte_simple_rnn_1.output_2 AS FLOAT) AS output_2, CAST(rnn_cte_simple_rnn_1.output_3 AS FLOAT) AS output_3
# FROM rnn_cte_simple_rnn_1),
# simple_rnn_1_1 AS
# (SELECT simple_rnn_1."KEY" AS "KEY", simple_rnn_1.output_1 AS output_1, simple_rnn_1.output_2 AS output_2, simple_rnn_1.output_3 AS output_3
# FROM simple_rnn_1),
# layer_dense_1 AS
# (SELECT simple_rnn_1_1."KEY" AS "KEY", 3.2233598232269287 + -2.453587770462036 * simple_rnn_1_1.output_1 + 3.02994966506958 * simple_rnn_1_1.output_2 + -2.554208755493164 * simple_rnn_1_1.output_3 AS output_1
# FROM simple_rnn_1_1)
#  SELECT layer_dense_1."KEY" AS "KEY", layer_dense_1.output_1 AS "Estimator"
# FROM layer_dense_1

# %% [markdown]
# # Execute the SQL Code

# %%
# save the dataset in a database table


import sqlalchemy as sa

#engine = sa.create_engine('sqlite://' , echo=False)
engine = sa.create_engine("postgresql://db:db@localhost/db?port=5432", echo=False)
conn = engine.connect()

lTable = pd.DataFrame(boston.data);
lTable.columns = lMetaData['features']
lTable['TGT'] = boston.target
lTable['KEY'] = range(boston.data.shape[0])
lTable.to_sql(lMetaData['table'] , conn,   if_exists='replace', index=False)
# Out:
# DEBUG:sqlalchemy.pool.QueuePool:Created new connection <connection object at 0x7f07c5e9b768; dsn: 'user=db password=xxx dbname=db host=localhost port=5432', closed: 0>
# INFO:sqlalchemy.engine.base.Engine:select version()
# INFO:sqlalchemy.engine.base.Engine:{}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('version',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('PostgreSQL 10.4 (Debian 10.4-2) on x86_64-pc-linux-gnu, compiled by gcc (Debian 7.3.0-18) 7.3.0, 64-bit',)
# INFO:sqlalchemy.engine.base.Engine:select current_schema()
# INFO:sqlalchemy.engine.base.Engine:{}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('current_schema',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('public',)
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:{}
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:{}
# INFO:sqlalchemy.engine.base.Engine:show standard_conforming_strings
# INFO:sqlalchemy.engine.base.Engine:{}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('standard_conforming_strings',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('on',)
# DEBUG:sqlalchemy.pool.QueuePool:Connection <connection object at 0x7f07c5e9b768; dsn: 'user=db password=xxx dbname=db host=localhost port=5432', closed: 0> checked out from pool
# INFO:sqlalchemy.engine.base.Engine:select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# INFO:sqlalchemy.engine.base.Engine:{'name': 'boston'}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('relname',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('boston',)
# INFO:sqlalchemy.engine.base.Engine:select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# INFO:sqlalchemy.engine.base.Engine:{'name': 'boston'}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('relname',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('boston',)
# INFO:sqlalchemy.engine.base.Engine:SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind = 'r'
# INFO:sqlalchemy.engine.base.Engine:{'schema': 'public'}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('relname',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_7_4_3FB79030',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_82_10_EA8E6ACF',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_22_10_D28EF166',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_7_10_C3DE2F26',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_82_4_DBD3B4F4',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_22_2_2E64DEB6',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_82_10_EA8E6ACF',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_O_200_7_2_F2617B35',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_R_50_22_0_D98398E5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_R_200_82_0_1FE01DA5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_PT_50_22_0_D98398E5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_PT_200_7_0_9526FA36',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_PT_200_82_0_1FE01DA5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('CODEGEN__50_5_0_A848294A',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('iris1',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_7_10_C3DE2F26',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_7_2_102297A5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_82_2_83B7053C',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_22_2_2E64DEB6',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_82_10_EA8E6ACF',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_22_4_9802FBBD',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_O_50_7_2_F2617B35',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_22_2_C38ADB8B',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_7_4_3FB79030',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_82_4_DBD3B4F4',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_22_4_9802FBBD',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_7_2_F2617B35',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_22_10_D28EF166',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_O_200_22_2_2E64DEB6',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_R_50_82_0_1FE01DA5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_T_50_7_0_9526FA36',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_T_50_82_0_1FE01DA5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_T_200_22_0_D98398E5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_22_4_9802FBBD',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_7_10_C3DE2F26',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_82_10_EA8E6ACF',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_22_10_D28EF166',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_7_4_3FB79030',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_82_2_7B21C547',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_O_50_22_2_2E64DEB6',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_O_200_82_2_7B21C547',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_R_200_7_0_9526FA36',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_PT_50_7_0_9526FA36',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_PT_50_82_0_1FE01DA5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_PT_200_22_0_D98398E5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_22_10_D28EF166',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_82_2_83B7053C',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_22_2_C38ADB8B',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_7_2_F2617B35',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_82_4_DBD3B4F4',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_200_22_4_9802FBBD',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_7_4_3FB79030',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_50_82_2_7B21C547',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_N_50_7_2_102297A5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_7_10_C3DE2F26',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_C_200_82_4_DBD3B4F4',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_O_50_82_2_7B21C547',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_R_50_7_0_9526FA36',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_R_200_22_0_D98398E5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_T_50_22_0_D98398E5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_T_200_7_0_9526FA36',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('BENCH_T_200_82_0_1FE01DA5',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('boston',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('CODEGEN__506_5_0_98AB0A96',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('CODEGEN__96_17_0_B9CDF81A',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('CODEGEN__506_6_0_8E32A7D1',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('CODEGEN__506_15_0_A5FCC092',)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('CODEGEN__96_3_0_3030680D',)
# INFO:sqlalchemy.engine.base.Engine:
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in ('r', 'v', 'm', 'f')
#
# INFO:sqlalchemy.engine.base.Engine:{'table_name': 'boston'}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('oid',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (1223006,)
# INFO:sqlalchemy.engine.base.Engine:
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
# INFO:sqlalchemy.engine.base.Engine:{'table_oid': 1223006}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('attname', 'format_type', 'default', 'attnotnull', 'attnum', 'table_oid', 'comment')
# DEBUG:sqlalchemy.engine.base.Engine:Row ('CRIM', 'double precision', None, False, 1, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('ZN', 'double precision', None, False, 2, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('INDUS', 'double precision', None, False, 3, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('CHAS', 'double precision', None, False, 4, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('NOX', 'double precision', None, False, 5, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('RM', 'double precision', None, False, 6, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('AGE', 'double precision', None, False, 7, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('DIS', 'double precision', None, False, 8, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('RAD', 'double precision', None, False, 9, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('TAX', 'double precision', None, False, 10, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('PTRATIO', 'double precision', None, False, 11, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('B', 'double precision', None, False, 12, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('LSTAT', 'double precision', None, False, 13, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('TGT', 'double precision', None, False, 14, 1223006, None)
# DEBUG:sqlalchemy.engine.base.Engine:Row ('KEY', 'bigint', None, False, 15, 1223006, None)
# INFO:sqlalchemy.engine.base.Engine:
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# INFO:sqlalchemy.engine.base.Engine:{}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('name', 'attype', 'nullable', 'default', 'visible', 'schema')
# DEBUG:sqlalchemy.engine.base.Engine:Row ('yes_or_no', 'character varying(3)', True, None, False, 'information_schema')
# DEBUG:sqlalchemy.engine.base.Engine:Row ('time_stamp', 'timestamp(2) with time zone', True, 'CURRENT_TIMESTAMP(2)', False, 'information_schema')
# DEBUG:sqlalchemy.engine.base.Engine:Row ('sql_identifier', 'character varying', True, None, False, 'information_schema')
# DEBUG:sqlalchemy.engine.base.Engine:Row ('character_data', 'character varying', True, None, False, 'information_schema')
# DEBUG:sqlalchemy.engine.base.Engine:Row ('cardinal_number', 'integer', True, None, False, 'information_schema')
# INFO:sqlalchemy.engine.base.Engine:
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# INFO:sqlalchemy.engine.base.Engine:{}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('name', 'visible', 'schema', 'label')
# INFO:sqlalchemy.engine.base.Engine:
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# INFO:sqlalchemy.engine.base.Engine:{'table_oid': 1223006}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('attname',)
# INFO:sqlalchemy.engine.base.Engine:
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# INFO:sqlalchemy.engine.base.Engine:{'table_oid': 1223006}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('conname',)
# INFO:sqlalchemy.engine.base.Engine:
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# INFO:sqlalchemy.engine.base.Engine:{'table': 1223006}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('conname', 'condef', 'conschema')
# INFO:sqlalchemy.engine.base.Engine:
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# INFO:sqlalchemy.engine.base.Engine:{'table_oid': 1223006}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('relname', 'indisunique', 'indexprs', 'indpred', 'attname', 'attnum', 'conrelid', 'indkey', 'reloptions', 'amname')
# INFO:sqlalchemy.engine.base.Engine:
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# INFO:sqlalchemy.engine.base.Engine:{'table_oid': 1223006}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('name', 'key', 'col_num', 'col_name')
# INFO:sqlalchemy.engine.base.Engine:
#             SELECT
#                 cons.conname as name,
#                 cons.consrc as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# INFO:sqlalchemy.engine.base.Engine:{'table_oid': 1223006}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('name', 'src')
# INFO:sqlalchemy.engine.base.Engine:
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# INFO:sqlalchemy.engine.base.Engine:{'table_oid': 1223006}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('table_comment',)
# INFO:sqlalchemy.engine.base.Engine:
# DROP TABLE boston CASCADE
# INFO:sqlalchemy.engine.base.Engine:{}
# INFO:sqlalchemy.engine.base.Engine:COMMIT
# INFO:sqlalchemy.engine.base.Engine:
# CREATE TABLE boston (
# 	"CRIM" FLOAT(53),
# 	"ZN" FLOAT(53),
# 	"INDUS" FLOAT(53),
# 	"CHAS" FLOAT(53),
# 	"NOX" FLOAT(53),
# 	"RM" FLOAT(53),
# 	"AGE" FLOAT(53),
# 	"DIS" FLOAT(53),
# 	"RAD" FLOAT(53),
# 	"TAX" FLOAT(53),
# 	"PTRATIO" FLOAT(53),
# 	"B" FLOAT(53),
# 	"LSTAT" FLOAT(53),
# 	"TGT" FLOAT(53),
# 	"KEY" BIGINT
# )
#
#
# INFO:sqlalchemy.engine.base.Engine:{}
# INFO:sqlalchemy.engine.base.Engine:COMMIT
# INFO:sqlalchemy.engine.base.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.base.Engine:INSERT INTO boston ("CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "TGT", "KEY") VALUES (%(CRIM)s, %(ZN)s, %(INDUS)s, %(CHAS)s, %(NOX)s, %(RM)s, %(AGE)s, %(DIS)s, %(RAD)s, %(TAX)s, %(PTRATIO)s, %(B)s, %(LSTAT)s, %(TGT)s, %(KEY)s)
# INFO:sqlalchemy.engine.base.Engine:({'CRIM': 0.00632, 'ZN': 18.0, 'INDUS': 2.31, 'CHAS': 0.0, 'NOX': 0.538, 'RM': 6.575, 'AGE': 65.2, 'DIS': 4.09, 'RAD': 1.0, 'TAX': 296.0, 'PTRATIO': 15.3, 'B': 396.9, 'LSTAT': 4.98, 'TGT': 24.0, 'KEY': 0}, {'CRIM': 0.02731, 'ZN': 0.0, 'INDUS': 7.07, 'CHAS': 0.0, 'NOX': 0.469, 'RM': 6.421, 'AGE': 78.9, 'DIS': 4.9671, 'RAD': 2.0, 'TAX': 242.0, 'PTRATIO': 17.8, 'B': 396.9, 'LSTAT': 9.14, 'TGT': 21.6, 'KEY': 1}, {'CRIM': 0.02729, 'ZN': 0.0, 'INDUS': 7.07, 'CHAS': 0.0, 'NOX': 0.469, 'RM': 7.185, 'AGE': 61.1, 'DIS': 4.9671, 'RAD': 2.0, 'TAX': 242.0, 'PTRATIO': 17.8, 'B': 392.83, 'LSTAT': 4.03, 'TGT': 34.7, 'KEY': 2}, {'CRIM': 0.03237, 'ZN': 0.0, 'INDUS': 2.18, 'CHAS': 0.0, 'NOX': 0.458, 'RM': 6.998, 'AGE': 45.8, 'DIS': 6.0622, 'RAD': 3.0, 'TAX': 222.0, 'PTRATIO': 18.7, 'B': 394.63, 'LSTAT': 2.94, 'TGT': 33.4, 'KEY': 3}, {'CRIM': 0.06905, 'ZN': 0.0, 'INDUS': 2.18, 'CHAS': 0.0, 'NOX': 0.458, 'RM': 7.147, 'AGE': 54.2, 'DIS': 6.0622, 'RAD': 3.0, 'TAX': 222.0, 'PTRATIO': 18.7, 'B': 396.9, 'LSTAT': 5.33, 'TGT': 36.2, 'KEY': 4}, {'CRIM': 0.02985, 'ZN': 0.0, 'INDUS': 2.18, 'CHAS': 0.0, 'NOX': 0.458, 'RM': 6.43, 'AGE': 58.7, 'DIS': 6.0622, 'RAD': 3.0, 'TAX': 222.0, 'PTRATIO': 18.7, 'B': 394.12, 'LSTAT': 5.21, 'TGT': 28.7, 'KEY': 5}, {'CRIM': 0.08829, 'ZN': 12.5, 'INDUS': 7.87, 'CHAS': 0.0, 'NOX': 0.524, 'RM': 6.012, 'AGE': 66.6, 'DIS': 5.5605, 'RAD': 5.0, 'TAX': 311.0, 'PTRATIO': 15.2, 'B': 395.6, 'LSTAT': 12.43, 'TGT': 22.9, 'KEY': 6}, {'CRIM': 0.14455, 'ZN': 12.5, 'INDUS': 7.87, 'CHAS': 0.0, 'NOX': 0.524, 'RM': 6.172, 'AGE': 96.1, 'DIS': 5.9505, 'RAD': 5.0, 'TAX': 311.0, 'PTRATIO': 15.2, 'B': 396.9, 'LSTAT': 19.15, 'TGT': 27.1, 'KEY': 7}  ... displaying 10 of 506 total bound parameter sets ...  {'CRIM': 0.10959, 'ZN': 0.0, 'INDUS': 11.93, 'CHAS': 0.0, 'NOX': 0.573, 'RM': 6.794, 'AGE': 89.3, 'DIS': 2.3889, 'RAD': 1.0, 'TAX': 273.0, 'PTRATIO': 21.0, 'B': 393.45, 'LSTAT': 6.48, 'TGT': 22.0, 'KEY': 504}, {'CRIM': 0.04741, 'ZN': 0.0, 'INDUS': 11.93, 'CHAS': 0.0, 'NOX': 0.573, 'RM': 6.03, 'AGE': 80.8, 'DIS': 2.505, 'RAD': 1.0, 'TAX': 273.0, 'PTRATIO': 21.0, 'B': 396.9, 'LSTAT': 7.88, 'TGT': 11.9, 'KEY': 505})
# INFO:sqlalchemy.engine.base.Engine:COMMIT

# %%
sql_output = pd.read_sql(lSQL , conn);
# Out:
# INFO:sqlalchemy.engine.base.Engine:select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# INFO:sqlalchemy.engine.base.Engine:{'name': 'WITH RECURSIVE keras_input AS \n(SELECT "ADS"."KEY" AS "KEY", "ADS"."CRIM" AS "CRIM", "ADS"."ZN" AS "ZN", "ADS"."INDUS" AS "INDUS", "ADS"."CHAS" AS " ... (13088 characters truncated) ... rnn_1_1.output_3 AS output_1 \nFROM simple_rnn_1_1)\n SELECT layer_dense_1."KEY" AS "KEY", layer_dense_1.output_1 AS "Estimator" \nFROM layer_dense_1'}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('relname',)
# INFO:sqlalchemy.engine.base.Engine:WITH RECURSIVE keras_input AS
# (SELECT "ADS"."KEY" AS "KEY", "ADS"."CRIM" AS "CRIM", "ADS"."ZN" AS "ZN", "ADS"."INDUS" AS "INDUS", "ADS"."CHAS" AS "CHAS", "ADS"."NOX" AS "NOX", "ADS"."RM" AS "RM", "ADS"."AGE" AS "AGE", "ADS"."DIS" AS "DIS", "ADS"."RAD" AS "RAD", "ADS"."TAX" AS "TAX", "ADS"."PTRATIO" AS "PTRATIO", "ADS"."B" AS "B", "ADS"."LSTAT" AS "LSTAT"
# FROM boston AS "ADS"),
# keras_input_1 AS
# (SELECT keras_input."KEY" AS "KEY", keras_input."CRIM" AS "CRIM", keras_input."ZN" AS "ZN", keras_input."INDUS" AS "INDUS", keras_input."CHAS" AS "CHAS", keras_input."NOX" AS "NOX", keras_input."RM" AS "RM", keras_input."AGE" AS "AGE", keras_input."DIS" AS "DIS", keras_input."RAD" AS "RAD", keras_input."TAX" AS "TAX", keras_input."PTRATIO" AS "PTRATIO", keras_input."B" AS "B", keras_input."LSTAT" AS "LSTAT"
# FROM keras_input),
# keras_input_1_rn AS
# (SELECT row_number() OVER (ORDER BY keras_input_1."KEY" ASC) AS rn, keras_input_1."KEY" AS "KEY", keras_input_1."CRIM" AS "CRIM", keras_input_1."ZN" AS "ZN", keras_input_1."INDUS" AS "INDUS", keras_input_1."CHAS" AS "CHAS", keras_input_1."NOX" AS "NOX", keras_input_1."RM" AS "RM", keras_input_1."AGE" AS "AGE", keras_input_1."DIS" AS "DIS", keras_input_1."RAD" AS "RAD", keras_input_1."TAX" AS "TAX", keras_input_1."PTRATIO" AS "PTRATIO", keras_input_1."B" AS "B", keras_input_1."LSTAT" AS "LSTAT"
# FROM keras_input_1),
# input_kernel_bias AS
# (SELECT keras_input_1_rn.rn AS rn, keras_input_1_rn."KEY" AS "KEY", keras_input_1_rn."CRIM" AS "CRIM", keras_input_1_rn."ZN" AS "ZN", keras_input_1_rn."INDUS" AS "INDUS", keras_input_1_rn."CHAS" AS "CHAS", keras_input_1_rn."NOX" AS "NOX", keras_input_1_rn."RM" AS "RM", keras_input_1_rn."AGE" AS "AGE", keras_input_1_rn."DIS" AS "DIS", keras_input_1_rn."RAD" AS "RAD", keras_input_1_rn."TAX" AS "TAX", keras_input_1_rn."PTRATIO" AS "PTRATIO", keras_input_1_rn."B" AS "B", keras_input_1_rn."LSTAT" AS "LSTAT", -0.1526474803686142 + -0.07609600573778152 * keras_input_1_rn."CRIM" + -0.04115665704011917 * keras_input_1_rn."ZN" + -0.16246578097343445 * keras_input_1_rn."INDUS" + 0.11817125976085663 * keras_input_1_rn."CHAS" + -0.22861920297145844 * keras_input_1_rn."NOX" + -0.4978691637516022 * keras_input_1_rn."RM" + 0.26714715361595154 * keras_input_1_rn."AGE" + -0.23344437777996063 * keras_input_1_rn."DIS" + -0.37154486775398254 * keras_input_1_rn."RAD" + 0.13552315533161163 * keras_input_1_rn."TAX" + -0.244401752948761 * keras_input_1_rn."PTRATIO" + -0.4090282618999481 * keras_input_1_rn."B" + -0.036395084112882614 * keras_input_1_rn."LSTAT" AS dot_prod_1, 0.0 + 0.1661962866783142 * keras_input_1_rn."CRIM" + 0.09738326072692871 * keras_input_1_rn."ZN" + -0.18801289796829224 * keras_input_1_rn."INDUS" + 0.44377070665359497 * keras_input_1_rn."CHAS" + -0.49438074231147766 * keras_input_1_rn."NOX" + 0.5940975546836853 * keras_input_1_rn."RM" + -0.14400193095207214 * keras_input_1_rn."AGE" + 0.5196391940116882 * keras_input_1_rn."DIS" + -0.08744961023330688 * keras_input_1_rn."RAD" + 0.3087066411972046 * keras_input_1_rn."TAX" + 0.255348265171051 * keras_input_1_rn."PTRATIO" + -0.0731934905052185 * keras_input_1_rn."B" + 0.34239959716796875 * keras_input_1_rn."LSTAT" AS dot_prod_2, 0.0 + -0.03524869680404663 * keras_input_1_rn."CRIM" + 0.39412933588027954 * keras_input_1_rn."ZN" + 0.20680874586105347 * keras_input_1_rn."INDUS" + -0.20028209686279297 * keras_input_1_rn."CHAS" + -0.4099527597427368 * keras_input_1_rn."NOX" + -0.41654878854751587 * keras_input_1_rn."RM" + -0.5328968167304993 * keras_input_1_rn."AGE" + 0.5520102381706238 * keras_input_1_rn."DIS" + -0.5709446668624878 * keras_input_1_rn."RAD" + -0.2293562889099121 * keras_input_1_rn."TAX" + -0.0009045004844665527 * keras_input_1_rn."PTRATIO" + -0.31112179160118103 * keras_input_1_rn."B" + 0.18181532621383667 * keras_input_1_rn."LSTAT" AS dot_prod_3
# FROM keras_input_1_rn),
# rnn_cte_simple_rnn_1(rn_1, "KEY", "PreviousState_1", "PreviousState_2", "PreviousState_3", output_1, output_2, output_3, "State_1", "State_2", "State_3") AS
# (SELECT input_kernel_bias.rn AS rn_1, input_kernel_bias."KEY" AS "KEY", CAST(0.0 AS FLOAT) AS "PreviousState_1", CAST(0.0 AS FLOAT) AS "PreviousState_2", CAST(0.0 AS FLOAT) AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0) + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * 0.0 + 0.016057631000876427 * 0.0 + 0.6978268623352051 * 0.0))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0) + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * 0.0 + -0.9468122720718384 * 0.0 + 0.32092922925949097 * 0.0))) AS "State_2", (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0) + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * 0.0 + 0.27593860030174255 * 0.0 + 0.7722214460372925 * 0.0))) AS "State_3"
# FROM input_kernel_bias
# WHERE input_kernel_bias.rn = 1 UNION ALL SELECT input_kernel_bias.rn AS rn, input_kernel_bias."KEY" AS "KEY", rnn_cte_simple_rnn_1."State_1" AS "PreviousState_1", rnn_cte_simple_rnn_1."State_2" AS "PreviousState_2", rnn_cte_simple_rnn_1."State_3" AS "PreviousState_3", (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) AS output_1, (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) AS output_2, (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_3 + 0.5723040699958801 * rnn_cte_simple_rnn_1."State_1" + 0.27593860030174255 * rnn_cte_simple_rnn_1."State_2" + 0.7722214460372925 * rnn_cte_simple_rnn_1."State_3"))) AS output_3, (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3") + exp(-(input_kernel_bias.dot_prod_1 + -0.7419068813323975 * rnn_cte_simple_rnn_1."State_1" + 0.016057631000876427 * rnn_cte_simple_rnn_1."State_2" + 0.6978268623352051 * rnn_cte_simple_rnn_1."State_3"))) AS "State_1", (exp(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3") - exp(-(input_kernel_bias.dot_prod_2 + 0.023472845554351807 * rnn_cte_simple_rnn_1."State_1" + -0.9468122720718384 * rnn_cte_simple_rnn_1."State_2" + 0.32092922925949097 * rnn_cte_simple_rnn_1."State_3"))) / (exp(input_kernel_bias.do ...
# FROM input_kernel_bias, rnn_cte_simple_rnn_1
# WHERE input_kernel_bias.rn = rnn_cte_simple_rnn_1.rn_1 + 1),
# simple_rnn_1 AS
# (SELECT rnn_cte_simple_rnn_1."KEY" AS "KEY", CAST(rnn_cte_simple_rnn_1.output_1 AS FLOAT) AS output_1, CAST(rnn_cte_simple_rnn_1.output_2 AS FLOAT) AS output_2, CAST(rnn_cte_simple_rnn_1.output_3 AS FLOAT) AS output_3
# FROM rnn_cte_simple_rnn_1),
# simple_rnn_1_1 AS
# (SELECT simple_rnn_1."KEY" AS "KEY", simple_rnn_1.output_1 AS output_1, simple_rnn_1.output_2 AS output_2, simple_rnn_1.output_3 AS output_3
# FROM simple_rnn_1),
# layer_dense_1 AS
# (SELECT simple_rnn_1_1."KEY" AS "KEY", 3.2233598232269287 + -2.453587770462036 * simple_rnn_1_1.output_1 + 3.02994966506958 * simple_rnn_1_1.output_2 + -2.554208755493164 * simple_rnn_1_1.output_3 AS output_1
# FROM simple_rnn_1_1)
#  SELECT layer_dense_1."KEY" AS "KEY", layer_dense_1.output_1 AS "Estimator"
# FROM layer_dense_1
# INFO:sqlalchemy.engine.base.Engine:{}
# DEBUG:sqlalchemy.engine.base.Engine:Col ('KEY', 'Estimator')
# DEBUG:sqlalchemy.engine.base.Engine:Row (0, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (1, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (2, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (3, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (4, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (5, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (6, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (7, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (8, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (9, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (10, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (11, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (12, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (13, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (14, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (15, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (16, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (17, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (18, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (19, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (20, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (21, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (22, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (23, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (24, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (25, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (26, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (27, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (28, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (29, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (30, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (31, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (32, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (33, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (34, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (35, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (36, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (37, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (38, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (39, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (40, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (41, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (42, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (43, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (44, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (45, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (46, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (47, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (48, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (49, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (50, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (51, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (52, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (53, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (54, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (55, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (56, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (57, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (58, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (59, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (60, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (61, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (62, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (63, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (64, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (65, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (66, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (67, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (68, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (69, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (70, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (71, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (72, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (73, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (74, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (75, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (76, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (77, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (78, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (79, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (80, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (81, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (82, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (83, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (84, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (85, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (86, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (87, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (88, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (89, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (90, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (91, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (92, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (93, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (94, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (95, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (96, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (97, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (98, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (99, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (100, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (101, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (102, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (103, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (104, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (105, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (106, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (107, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (108, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (109, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (110, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (111, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (112, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (113, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (114, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (115, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (116, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (117, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (118, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (119, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (120, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (121, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (122, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (123, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (124, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (125, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (126, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (127, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (128, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (129, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (130, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (131, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (132, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (133, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (134, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (135, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (136, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (137, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (138, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (139, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (140, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (141, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (142, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (143, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (144, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (145, 11.2461080021068)
# DEBUG:sqlalchemy.engine.base.Engine:Row (146, 10.3795423313558)
# DEBUG:sqlalchemy.engine.base.Engine:Row (147, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (148, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (149, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (150, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (151, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (152, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (153, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (154, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (155, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (156, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (157, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (158, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (159, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (160, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (161, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (162, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (163, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (164, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (165, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (166, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (167, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (168, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (169, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (170, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (171, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (172, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (173, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (174, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (175, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (176, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (177, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (178, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (179, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (180, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (181, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (182, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (183, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (184, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (185, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (186, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (187, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (188, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (189, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (190, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (191, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (192, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (193, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (194, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (195, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (196, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (197, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (198, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (199, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (200, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (201, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (202, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (203, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (204, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (205, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (206, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (207, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (208, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (209, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (210, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (211, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (212, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (213, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (214, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (215, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (216, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (217, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (218, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (219, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (220, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (221, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (222, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (223, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (224, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (225, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (226, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (227, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (228, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (229, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (230, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (231, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (232, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (233, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (234, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (235, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (236, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (237, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (238, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (239, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (240, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (241, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (242, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (243, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (244, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (245, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (246, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (247, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (248, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (249, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (250, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (251, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (252, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (253, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (254, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (255, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (256, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (257, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (258, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (259, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (260, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (261, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (262, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (263, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (264, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (265, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (266, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (267, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (268, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (269, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (270, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (271, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (272, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (273, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (274, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (275, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (276, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (277, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (278, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (279, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (280, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (281, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (282, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (283, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (284, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (285, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (286, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (287, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (288, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (289, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (290, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (291, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (292, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (293, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (294, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (295, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (296, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (297, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (298, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (299, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (300, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (301, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (302, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (303, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (304, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (305, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (306, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (307, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (308, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (309, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (310, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (311, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (312, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (313, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (314, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (315, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (316, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (317, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (318, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (319, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (320, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (321, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (322, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (323, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (324, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (325, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (326, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (327, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (328, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (329, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (330, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (331, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (332, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (333, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (334, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (335, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (336, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (337, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (338, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (339, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (340, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (341, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (342, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (343, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (344, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (345, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (346, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (347, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (348, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (349, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (350, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (351, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (352, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (353, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (354, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (355, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (356, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (357, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (358, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (359, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (360, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (361, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (362, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (363, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (364, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (365, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (366, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (367, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (368, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (369, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (370, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (371, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (372, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (373, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (374, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (375, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (376, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (377, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (378, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (379, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (380, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (381, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (382, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (383, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (384, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (385, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (386, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (387, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (388, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (389, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (390, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (391, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (392, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (393, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (394, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (395, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (396, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (397, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (398, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (399, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (400, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (401, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (402, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (403, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (404, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (405, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (406, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (407, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (408, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (409, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (410, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (411, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (412, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (413, 6.35394624311346)
# DEBUG:sqlalchemy.engine.base.Engine:Row (414, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (415, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (416, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (417, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (418, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (419, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (420, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (421, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (422, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (423, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (424, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (425, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (426, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (427, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (428, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (429, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (430, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (431, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (432, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (433, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (434, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (435, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (436, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (437, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (438, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (439, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (440, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (441, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (442, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (443, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (444, 11.2605775236342)
# DEBUG:sqlalchemy.engine.base.Engine:Row (445, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (446, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (447, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (448, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (449, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (450, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (451, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (452, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (453, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (454, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (455, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (456, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (457, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (458, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (459, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (460, 11.2611060140845)
# DEBUG:sqlalchemy.engine.base.Engine:Row (461, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (462, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (463, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (464, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (465, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (466, 6.35393047332764)
# DEBUG:sqlalchemy.engine.base.Engine:Row (467, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (468, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (469, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (470, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (471, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (472, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (473, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (474, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (475, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (476, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (477, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (478, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (479, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (480, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (481, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (482, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (483, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (484, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (485, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (486, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (487, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (488, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (489, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (490, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (491, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (492, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (493, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (494, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (495, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (496, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (497, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (498, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (499, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (500, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (501, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (502, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (503, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (504, 11.2611060142517)
# DEBUG:sqlalchemy.engine.base.Engine:Row (505, 11.2611060142517)

# %%
sql_output.sample(12, random_state=1960)
# Out:
#      KEY  Estimator
# 230  230  11.261106
# 112  112  11.261106
# 125  125  11.261106
# 9      9  11.261106
# 213  213  11.261106
# 109  109  11.261106
# 127  127  11.261106
# 244  244  11.261106
# 406  406  11.261106
# 490  490  11.261106
# 245  245  11.261106
# 133  133  11.261106

# %% [markdown]
# # Keras Prediction

# %%
skl_output = pd.DataFrame()
skl_output_key = pd.DataFrame(list(range(boston.data.shape[0])), columns=['KEY']);
data = boston.data.reshape(boston.data.shape[0] , 1, boston.data.shape[1])
skl_out = clf.predict(data)
print(skl_out.shape)
skl_output_estimator = pd.DataFrame(skl_out, columns=['Estimator'])
skl_output['KEY'] = skl_output_key['KEY']
skl_output['Estimator'] = skl_output_estimator
skl_output.sample(12, random_state=1960)
# Out:
# (506,)
#      KEY  Estimator
# 230  230  11.261106
# 112  112  11.261106
# 125  125  11.261106
# 9      9  11.261106
# 213  213  11.261106
# 109  109  11.261106
# 127  127  11.261106
# 244  244  11.261106
# 406  406  11.261106
# 490  490  11.261106
# 245  245  11.261106
# 133  133  11.261106

# %% [markdown]
# # Comparing the SQL and Keras Predictions

# %%
sql_skl_join = skl_output.join(sql_output , how='left', on='KEY', lsuffix='_skl', rsuffix='_sql')
sql_skl_join['Error'] = sql_skl_join.Estimator_sql - sql_skl_join.Estimator_skl

# %%
sql_skl_join.head(12)
# Out:
#     KEY_skl  Estimator_skl  KEY_sql  Estimator_sql         Error
# 0         0      11.261106        0      11.261106 -4.768372e-07
# 1         1      11.261106        1      11.261106 -4.768372e-07
# 2         2      11.261106        2      11.261106 -4.768372e-07
# 3         3      11.261106        3      11.261106 -4.768372e-07
# 4         4      11.261106        4      11.261106 -4.768372e-07
# 5         5      11.261106        5      11.261106 -4.768372e-07
# 6         6      11.261106        6      11.261106 -4.768372e-07
# 7         7      11.261106        7      11.261106 -4.768372e-07
# 8         8      11.261106        8      11.261106 -4.768372e-07
# 9         9      11.261106        9      11.261106 -4.768372e-07
# 10       10      11.261106       10      11.261106 -4.768372e-07
# 11       11      11.261106       11      11.261106 -4.768372e-07

# %%
sql_skl_join.describe()
# Out:
#           KEY_skl  Estimator_skl     KEY_sql  Estimator_sql         Error
# count  506.000000     506.000000  506.000000     506.000000  5.060000e+02
# mean   252.500000      10.890812  252.500000      10.890810 -4.366978e-07
# std    146.213884       1.294657  146.213884       1.294657  1.628615e-07
# min      0.000000       6.353930    0.000000       6.353930 -6.318834e-07
# 25%    126.250000      11.261106  126.250000      11.261106 -4.768372e-07
# 50%    252.500000      11.261106  252.500000      11.261106 -4.768372e-07
# 75%    378.750000      11.261106  378.750000      11.261106 -4.768372e-07
# max    505.000000      11.261106  505.000000      11.261106  1.887935e-06
